# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Datasets/nba.csv")

df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df.describe
# Out:
# <bound method NDFrame.describe of               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# ...

# %%
df.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
df['College'].count()
# Out:
# np.int64(373)

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df["Name"].fillna(df["Name"].mode()[0], inplace = True )

# %%
df["Team"].fillna(df["Team"].mode()[0], inplace = True )

# %%
df["Position"].fillna(df["Position"].mode()[0], inplace = True )

# %%
df["Height"].fillna(df["Height"].mode()[0], inplace = True )

# %%
df["College"].fillna(df["College"].mode()[0], inplace = True )

# %%
df["Number"].fillna(df["Number"].mean(), inplace = True )

# %%
df["Age"].fillna(df["Age"].mean(), inplace = True )

# %%
df["Weight"].fillna(df["Weight"].mean(), inplace = True )

# %%
df["Salary"].fillna(df["Salary"].mean(), inplace = True )

# %%
df.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (458, 9)

# %%
numeric_cols = ['Number', 'Age']
scaler = StandardScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])
df
# Out:
#               Name                  Team        Number Position           Age  \
# 0    Avery Bradley        Boston Celtics -1.109668e+00       PG -4.411831e-01
# 1      Jae Crowder        Boston Celtics  5.104556e+00       SF -4.411831e-01
# 2     John Holland        Boston Celtics  7.734301e-01       SG  1.394258e-02
# 3      R.J. Hunter        Boston Celtics  6.478902e-01       SG -1.123872e+00
# 4    Jonas Jerebko        Boston Celtics -6.075087e-01       PF  4.690683e-01
# ..             ...                   ...           ...      ...           ...
# 453   Shelvin Mack             Utah Jazz -6.075087e-01       PG -2.136203e-01
# 454      Raul Neto             Utah Jazz  4.595804e-01       PG -6.687460e-01
# 455   Tibor Pleiss             Utah Jazz  2.085006e-01        C -2.136203e-01
# 456    Jeff Withey             Utah Jazz  3.968104e-01        C -2.136203e-01
# 457   Aaron Brooks  New Orleans Pelicans -1.008412e-16       SG  1.939254e-16
#
# ...

# %% [markdown]
# sns.boxplot(df)

# %%
sns.set(style="whitegrid")
numeric_df = df.select_dtypes(include=['float64', 'int64'])


plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
total_texas = (df['College'] == 'Marquette').sum()
print(total_texas)
# Out:
# 5

# %%
total_texas = (df['College'] == 'Marquette').sum()
print(total_texas)
# Out:
# 5

# %%
print(df['College'].value_counts())
# Out:
# College
# Kentucky           107
# Duke                20
# Kansas              18
# North Carolina      16
# UCLA                15
#                   ...
# Utah Valley          1
# Cleveland State      1
# Iowa State           1
# Florida State        1
# Baylor               1
# Name: count, Length: 118, dtype: int64

# %%
# Check if your dataset has a 'Number' column for jersey numbers
if 'Number' in df.columns:
    # Calculate average salary for each jersey number
    number_avg_salary = df.groupby('Number')['Salary'].mean()
    
    # Find the jersey number with the highest average salary
    lucky_number = number_avg_salary.idxmax()
    lucky_number_avg_salary = number_avg_salary.max()
    
    print("Lucky Jersey Number:", lucky_number)
    print("Highest Average Salary for that Number:", lucky_number_avg_salary)
else:
    print("Dataset does not contain a 'Number' column for jersey numbers.")
# Out:
# Lucky Jersey Number: 4.539626658306809
# Highest Average Salary for that Number: 0.5446351202416397

# %%
df.count()
# Out:
# Name        458
# Team        458
# Number      458
# Position    458
# Age         458
# Height      458
# Weight      458
# College     458
# Salary      458
# dtype: int64

# %%
print(df['College'].value_counts())
# Out:
# College
# Kentucky           107
# Duke                20
# Kansas              18
# North Carolina      16
# UCLA                15
#                   ...
# Utah Valley          1
# Cleveland State      1
# Iowa State           1
# Florida State        1
# Baylor               1
# Name: count, Length: 118, dtype: int64

# %%
sns.pairplot(df, vars=['Number', 'Age', 'Weight', 'Salary'])
plt.suptitle('Pairplot of Numeric Features by Position')
plt.show()

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Position', y='Salary')
plt.title('Salary Distribution by Position')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
team_counts = df['Team'].value_counts()
sns.barplot(x=team_counts.index, color = "red" ,y=team_counts.values)
plt.xticks(rotation=90)
plt.title('Number of Players per Team')
plt.xlabel('Team')
plt.ylabel('Number of Players')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
age_salary = df.groupby('Age')['Salary'].mean().sort_index()
plt.plot(age_salary.index, age_salary.values, color = "b" , marker='o', linestyle='--')
plt.title('Average Salary by Age')
plt.xlabel('Age')
plt.ylabel('Average Salary')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(7, 7))
position_counts = df['Position'].value_counts()
plt.pie(position_counts, labels=position_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Player Distribution by Position')
plt.axis('equal')  
plt.show()

# %%
top_paid = df[['Name', 'Salary']].sort_values(by='Salary', ascending=False).head(10)

plt.figure(figsize=(12, 6))
sns.barplot(data=top_paid, x='Salary', y='Name', palette='viridis')
plt.title('Top 10 Highest Paid NBA Players')
plt.xlabel('Salary')
plt.ylabel('Player Name')
plt.show()

# %% [markdown]
# # Genral Findings:-
# 1. kobe byrant has highest salary
# 2. New orleans pelicans has highest number of players
# 3. Position C has higher salary as compared to others

# %% [markdown]
# # Correlation findings:-
# 1. The columns age and numbers has almost no correlation
# 2. The coloums number and weight are wealky correlated
# 3. The columns number and salary are regularly correlated
# 4.
